# %% [markdown]
# # Importing all the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load all the datasets

# %%
df = pd.read_json("tables.json")
df_dev = pd.read_json("dev.json")
df_others = pd.read_json("train_others.json")
df_spider = pd.read_json("train_spider.json")

# %% [markdown]
# # Analyzing data of the datsets

# %%
df
# Out:
#                                           column_names  \
# 0    [[-1, *], [0, perpetrator id], [0, people id],...
# 1    [[-1, *], [0, building], [0, room number], [0,...
# 2    [[-1, *], [0, id], [0, city], [0, country], [0...
# 3    [[-1, *], [0, institution id], [0, name], [0, ...
# 4    [[-1, *], [0, body builder id], [0, people id]...
# ..                                                 ...
# 161  [[-1, *], [0, employee ssn], [0, project numbe...
# 162  [[-1, *], [0, workshop id], [0, date], [0, ven...
# 163  [[-1, *], [0, item id], [0, title], [1, a id],...
# 164  [[-1, *], [0, party id], [0, party theme], [0,...
# 165  [[-1, *], [0, attribute id], [0, attribute nam...
#
#                                  column_names_original  \
# 0    [[-1, *], [0, Perpetrator_ID], [0, People_ID],...
# 1    [[-1, *], [0, building], [0, room_number], [0,...
# 2    [[-1, *], [0, id], [0, City], [0, Country], [0...
# 3    [[-1, *], [0, instID], [0, name], [0, country]...
# ...

# %%
df["db_id"]
# Out:
# 0          perpetrator
# 1            college_2
# 2       flight_company
# 3               icfp_1
# 4         body_builder
#             ...
# 161          company_1
# 162     workshop_paper
# 163         epinions_1
# 164         party_host
# 165    product_catalog
# Name: db_id, Length: 166, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   column_names           166 non-null    object
#  1   column_names_original  166 non-null    object
#  2   column_types           166 non-null    object
#  3   db_id                  166 non-null    object
#  4   foreign_keys           166 non-null    object
#  5   primary_keys           166 non-null    object
#  6   table_names            166 non-null    object
#  7   table_names_original   166 non-null    object
# dtypes: object(8)
# memory usage: 10.5+ KB

# %%
df["db_id"].value_counts()
# Out:
# apartment_rentals              1
# college_3                      1
# dorm_1                         1
# company_office                 1
# party_people                   1
#                               ..
# tracking_software_problems     1
# railway                        1
# news_report                    1
# tracking_share_transactions    1
# film_rank                      1
# Name: db_id, Length: 166, dtype: int64

# %%
df_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   db_id                1034 non-null   object
#  1   query                1034 non-null   object
#  2   query_toks           1034 non-null   object
#  3   query_toks_no_value  1034 non-null   object
#  4   question             1034 non-null   object
#  5   question_toks        1034 non-null   object
#  6   sql                  1034 non-null   object
# dtypes: object(7)
# memory usage: 56.7+ KB

# %%
df_dev["db_id"].value_counts()
# Out:
# world_1                         120
# car_1                            92
# cre_Doc_Template_Mgt             84
# dog_kennels                      82
# flight_2                         80
# student_transcripts_tracking     78
# wta_1                            62
# tvshow                           62
# network_1                        56
# concert_singer                   45
# pets_1                           42
# poker_player                     40
# orchestra                        40
# employee_hire_evaluation         38
# course_teach                     30
# singer                           30
# museum_visit                     18
# battle_death                     16
# voter_1                          15
# real_estate_properties            4
# Name: db_id, dtype: int64

# %%
df_dev
# Out:
#                        db_id  \
# 0             concert_singer
# 1             concert_singer
# 2             concert_singer
# 3             concert_singer
# 4             concert_singer
# ...                      ...
# 1029                  singer
# 1030  real_estate_properties
# 1031  real_estate_properties
# 1032  real_estate_properties
# 1033  real_estate_properties
#
#                                                   query  \
# 0                           SELECT count(*) FROM singer
# 1                           SELECT count(*) FROM singer
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 3     SELECT name ,  country ,  age FROM singer ORDE...
# 4     SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# ...                                                 ...
# 1029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# 1030      SELECT count(*) FROM Other_Available_Features
# 1031  SELECT T2.feature_type_name FROM Other_Availab...
# ...

# %%
df_others.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1659 entries, 0 to 1658
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   db_id                1659 non-null   object
#  1   query                1659 non-null   object
#  2   query_toks           1659 non-null   object
#  3   query_toks_no_value  1659 non-null   object
#  4   question             1659 non-null   object
#  5   question_toks        1659 non-null   object
#  6   sql                  1659 non-null   object
# dtypes: object(7)
# memory usage: 90.9+ KB

# %%
df_others["db_id"].value_counts()
# Out:
# scholar        569
# geo            564
# academic       181
# restaurants    125
# yelp           111
# imdb           109
# Name: db_id, dtype: int64

# %%
df_others
# Out:
#             db_id                                              query  \
# 0             geo  SELECT city_name FROM city WHERE population  =...
# 1             geo  SELECT city_name FROM city WHERE population  =...
# 2             geo  SELECT city_name FROM city WHERE population  =...
# 3             geo  SELECT city_name FROM city WHERE population  =...
# 4             geo  SELECT city_name FROM city WHERE population  =...
# ...           ...                                                ...
# 1654  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1655  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1656  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1657  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
# 1658  restaurants  SELECT t2.house_number  ,  t1.name FROM LOCATI...
#
#                                              query_toks  \
# 0     [SELECT, city_name, FROM, city, WHERE, populat...
# ...

# %%
df_spider.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   db_id                7000 non-null   object
#  1   query                7000 non-null   object
#  2   query_toks           7000 non-null   object
#  3   query_toks_no_value  7000 non-null   object
#  4   question             7000 non-null   object
#  5   question_toks        7000 non-null   object
#  6   sql                  7000 non-null   object
# dtypes: object(7)
# memory usage: 382.9+ KB

# %%
df_spider["db_id"].value_counts()
# Out:
# college_2                 170
# college_1                 164
# hr_1                      124
# store_1                   112
# soccer_2                  106
#                          ...
# local_govt_in_alabama      15
# decoration_competition     15
# soccer_1                   14
# local_govt_mdm             14
# company_1                   7
# Name: db_id, Length: 140, dtype: int64

# %%
df_spider
# Out:
#                       db_id  \
# 0     department_management
# 1     department_management
# 2     department_management
# 3     department_management
# 4     department_management
# ...                     ...
# 6995        culture_company
# 6996        culture_company
# 6997        culture_company
# 6998        culture_company
# 6999        culture_company
#
#                                                   query  \
# 0            SELECT count(*) FROM head WHERE age  >  56
# 1     SELECT name ,  born_state ,  age FROM head ORD...
# 2     SELECT creation ,  name ,  budget_in_billions ...
# 3     SELECT max(budget_in_billions) ,  min(budget_i...
# 4     SELECT avg(num_employees) FROM department WHER...
# ...                                                 ...
# 6995  SELECT T1.company_name FROM culture_company AS...
# 6996  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6997  SELECT T1.title ,  T3.book_title FROM movie AS...
# ...

# %% [markdown]
# ## Plotting the frequency of data for each dataset

# %%
# count plot on single categorical variable
sns.set(rc={"figure.figsize":(8,3)})
sns.countplot(y ='db_id', data = df_dev)
plt.savefig( "df_dev.pdf" , dpi=1200)
# Show the plot
plt.show()

# %%
# count plot on single categorical variable
sns.countplot(y ='db_id', data = df_others,)
plt.savefig( "df_others.pdf" , dpi=1200)
# Show the plot
plt.show()

# %%
# count plot on single categorical variable
sns.set(rc={"figure.figsize":(8, 25)})
sns.countplot(y ='db_id', data = df_spider)
plt.savefig( "df_spider.pdf" , dpi=1200)
# Show the plot
plt.show()

# %% [markdown]
# ## Selecting 1000 rows from 9693 total data

# %%
len(df_dev["db_id"].unique())
# Out:
# 20

# %%
len(df_others["db_id"].unique())
# Out:
# 6

# %%
len(df_spider["db_id"].unique())
# Out:
# 140

# %%
len(df["db_id"])
# Out:
# 166

# %% [markdown]
# Total Data = 7000(spider) + 1659(others) + 1034(dev) = 9693
#
# Data to be selected = 1000
#
# Percentage of data to be selected from the whole(combined) dataset and from each db_id = (1000/9693) * 100 = 10.31%

# %% [markdown]
# ## Function that extracts the given percentage of values from the dataset

# %% [markdown]
# The selection functions takes the dataframe as an argument and randomly selects the the number of rows based on the percentage and appends it to a new dataframe called "data".

# %%
data = pd.DataFrame()
def selection(df):
    global data
    for value in df["db_id"].unique():
        val = df.loc[df["db_id"] == value]
        rows = val.sample(n = int(round((len(val) * 0.103) , 0)) )
        data = data.append(rows)

# %%
selection(df_dev)

# %%
selection(df_others)

# %%
selection(df_spider)

# %% [markdown]
# ### final dataset comprising of 999 rows

# %%
data
# Out:
#                 db_id                                              query  \
# 2      concert_singer  SELECT name ,  country ,  age FROM singer ORDE...
# 25     concert_singer  select t2.name ,  t2.capacity from concert as ...
# 17     concert_singer  select avg(capacity) ,  max(capacity) from sta...
# 43     concert_singer  select count(*) from concert where stadium_id ...
# 34     concert_singer  select t2.concert_name ,  t2.theme ,  count(*)...
# ...               ...                                                ...
# 6957     architecture   SELECT name FROM mill WHERE name LIKE '%Moulin%'
# 6991  culture_company  SELECT director FROM movie WHERE YEAR  =  1999...
# 6982  culture_company  SELECT title ,  YEAR ,  director FROM movie OR...
# 6981  culture_company  SELECT publisher FROM book_club EXCEPT SELECT ...
# 6986  culture_company  SELECT title ,  director FROM movie WHERE YEAR...
#
#                                              query_toks  \
# ...

# %%
data["db_id"].value_counts()
# Out:
# scholar                 59
# geo                     58
# academic                19
# college_2               18
# college_1               17
#                         ..
# restaurant_1             2
# entertainment_awards     2
# soccer_1                 1
# company_1                1
# local_govt_mdm           1
# Name: db_id, Length: 165, dtype: int64

# %% [markdown]
# ### Adding of 1 row to make it to 1000

# %% [markdown]
# Since the selection fucntions selects the data only from those db_id values that are of length greater than 4, hence the db_id: "real_estate_properties" was dropped by the function which is then added manually to make the whole 1000 rows dataset.

# %%
val = df_dev.loc[df_dev["db_id"] == 'real_estate_properties']
rows = val.sample()
data = data.append(rows)

# %%
data
# Out:
#                        db_id  \
# 2             concert_singer
# 25            concert_singer
# 17            concert_singer
# 43            concert_singer
# 34            concert_singer
# ...                      ...
# 6991         culture_company
# 6982         culture_company
# 6981         culture_company
# 6986         culture_company
# 1033  real_estate_properties
#
#                                                   query  \
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 25    select t2.name ,  t2.capacity from concert as ...
# 17    select avg(capacity) ,  max(capacity) from sta...
# 43    select count(*) from concert where stadium_id ...
# 34    select t2.concert_name ,  t2.theme ,  count(*)...
# ...                                                 ...
# 6991  SELECT director FROM movie WHERE YEAR  =  1999...
# 6982  SELECT title ,  YEAR ,  director FROM movie OR...
# 6981  SELECT publisher FROM book_club EXCEPT SELECT ...
# ...

# %% [markdown]
# ### Analyzing Frequency of length of question in the dataset

# %% [markdown]
# Appending the length of each question in the dataset to plot the graph of their frequency.

# %%
len(df_dev["question_toks"])
# Out:
# 1034

# %%
def string_length(str):
    x = len(str)
    return x

data['question_toks_length'] = data['question_toks'].apply(lambda x: string_length(x))

# %%
data
# Out:
#                        db_id  \
# 2             concert_singer
# 25            concert_singer
# 17            concert_singer
# 43            concert_singer
# 34            concert_singer
# ...                      ...
# 6991         culture_company
# 6982         culture_company
# 6981         culture_company
# 6986         culture_company
# 1033  real_estate_properties
#
#                                                   query  \
# 2     SELECT name ,  country ,  age FROM singer ORDE...
# 25    select t2.name ,  t2.capacity from concert as ...
# 17    select avg(capacity) ,  max(capacity) from sta...
# 43    select count(*) from concert where stadium_id ...
# 34    select t2.concert_name ,  t2.theme ,  count(*)...
# ...                                                 ...
# 6991  SELECT director FROM movie WHERE YEAR  =  1999...
# 6982  SELECT title ,  YEAR ,  director FROM movie OR...
# 6981  SELECT publisher FROM book_club EXCEPT SELECT ...
# ...

# %%
x = data["question_toks_length"]
plt.figure(figsize=(8,8))
plt.hist(x, bins=10)
plt.xlabel('Length of Questions')
plt.ylabel('Frequency of Questions')
plt.savefig( "Length-of-questions-freq.pdf" , dpi=1200)
plt.show()
